# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
#lat_range = (-90, 90)
#lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=600)
lngs = np.random.uniform(low=-180.000, high=180.000, size=600)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city.capitalize())

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#api call
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
#create Data Frame
city_df = pd.DataFrame()

x = 1

for city in cities:
    query_url = f"{base_url}appid={api_keys}&q={city}&units={units}"
    print(f"Processing record {x} of {len(cities)}: {city}")

#weather data from operweathermap
    data = requests.get(query_url).json()

#for errors
    try:
        city_df.loc[x, "City"] = data["name"]
        city_df.loc[x, "Country"] = data['sys']['country']
        city_df.loc[x, "Date"] = str(data["dt"])
        city_df.loc[x, "Latitude"] = data["coord"]["lat"]
        city_df.loc[x, "Longitude"] = data["coord"]["lon"]
        city_df.loc[x, "Max Temp (F)"] = data["main"]["temp_max"]
        city_df.loc[x, "Humidity (%)"]= data["main"]["humidity"]
        city_df.loc[x, "Cloudiness (%)"]= data["clouds"]["all"]
        city_df.loc[x, "Wind Speed (mph)"]= data["wind"]["speed"]
    except:
        print("Not Found")
    x +=1
# Out:
# Processing record 1 of 600: Larsnes
# Not Found
# Processing record 2 of 600: Chernyshevskiy
# Not Found
# Processing record 3 of 600: Udachnyy
# Not Found
# Processing record 4 of 600: Vaitupu
# Not Found
# Processing record 5 of 600: Akcakoca
# Not Found
# Processing record 6 of 600: Bredasdorp
# Not Found
# Processing record 7 of 600: Souillac
# Not Found
# Processing record 8 of 600: Rikitea
# Not Found
# Processing record 9 of 600: Grand gaube
# Not Found
# Processing record 10 of 600: Grindavik
# Not Found
# Processing record 11 of 600: Longyearbyen
# Not Found
# Processing record 12 of 600: Mataura
# Not Found
# Processing record 13 of 600: Kapaa
# Not Found
# Processing record 14 of 600: Vostok
# Not Found
# Processing record 15 of 600: Tecoanapa
# Not Found
# Processing record 16 of 600: Beringovskiy
# Not Found
# Processing record 17 of 600: Flinders
# Not Found
# Processing record 18 of 600: Ushuaia
# Not Found
# Processing record 19 of 600: Alofi
# Not Found
# Processing record 20 of 600: Torbay
# Not Found
# Processing record 21 of 600: Busselton
# Not Found
# Processing record 22 of 600: Avarua
# Not Found
# Processing record 23 of 600: Ribeira grande
# Not Found
# Processing record 24 of 600: Airai
# Not Found
# Processing record 25 of 600: Verkhnyaya inta
# Not Found
# Processing record 26 of 600: Dikson
# Not Found
# Processing record 27 of 600: Mahebourg
# Not Found
# Processing record 28 of 600: Luwuk
# Not Found
# Processing record 29 of 600: Barentsburg
# Not Found
# Processing record 30 of 600: Punta arenas
# Not Found
# Processing record 31 of 600: Albany
# Not Found
# Processing record 32 of 600: Hobart
# Not Found
# Processing record 33 of 600: Nanortalik
# Not Found
# Processing record 34 of 600: Vaini
# Not Found
# Processing record 35 of 600: Abu dhabi
# Not Found
# Processing record 36 of 600: Ushuaia
# Not Found
# Processing record 37 of 600: Capao bonito
# Not Found
# Processing record 38 of 600: Mataura
# Not Found
# Processing record 39 of 600: Aklavik
# Not Found
# Processing record 40 of 600: Rikitea
# Not Found
# Processing record 41 of 600: Pontianak
# Not Found
# Processing record 42 of 600: Ekhabi
# Not Found
# Processing record 43 of 600: Hermanus
# Not Found
# Processing record 44 of 600: Tsihombe
# Not Found
# Processing record 45 of 600: Vardo
# Not Found
# Processing record 46 of 600: Butaritari
# Not Found
# Processing record 47 of 600: Dikson
# Not Found
# Processing record 48 of 600: Lebu
# Not Found
# Processing record 49 of 600: Puerto colombia
# Not Found
# Processing record 50 of 600: Punta arenas
# Not Found
# Processing record 51 of 600: Bubaque
# Not Found
# Processing record 52 of 600: Luderitz
# Not Found
# Processing record 53 of 600: New norfolk
# Not Found
# Processing record 54 of 600: Guaymas
# Not Found
# Processing record 55 of 600: Dunedin
# Not Found
# Processing record 56 of 600: Port lincoln
# Not Found
# Processing record 57 of 600: Weligama
# Not Found
# Processing record 58 of 600: Constitucion
# Not Found
# Processing record 59 of 600: Oxelosund
# Not Found
# Processing record 60 of 600: Rikitea
# Not Found
# Processing record 61 of 600: Hilo
# Not Found
# Processing record 62 of 600: Cidreira
# Not Found
# Processing record 63 of 600: Hithadhoo
# Not Found
# Processing record 64 of 600: Port alfred
# Not Found
# Processing record 65 of 600: Punta arenas
# Not Found
# Processing record 66 of 600: Talnakh
# Not Found
# Processing record 67 of 600: Kapaa
# Not Found
# Processing record 68 of 600: Taolanaro
# Not Found
# Processing record 69 of 600: Lockport
# Not Found
# Processing record 70 of 600: Nanortalik
# Not Found
# Processing record 71 of 600: Rikitea
# Not Found
# Processing record 72 of 600: Mataura
# Not Found
# Processing record 73 of 600: Ushuaia
# Not Found
# Processing record 74 of 600: Pyapon
# Not Found
# Processing record 75 of 600: Dikson
# Not Found
# Processing record 76 of 600: Megion
# Not Found
# Processing record 77 of 600: Illoqqortoormiut
# Not Found
# Processing record 78 of 600: Albany
# Not Found
# Processing record 79 of 600: Portland
# Not Found
# Processing record 80 of 600: Sola
# Not Found
# Processing record 81 of 600: Rosarito
# Not Found
# Processing record 82 of 600: Iqaluit
# Not Found
# Processing record 83 of 600: Rikitea
# Not Found
# Processing record 84 of 600: Hermanus
# Not Found
# Processing record 85 of 600: Hilo
# Not Found
# Processing record 86 of 600: Ushuaia
# Not Found
# Processing record 87 of 600: Bluff
# Not Found
# Processing record 88 of 600: Kushmurun
# Not Found
# Processing record 89 of 600: Saskylakh
# Not Found
# Processing record 90 of 600: Hay river
# Not Found
# Processing record 91 of 600: Taolanaro
# Not Found
# Processing record 92 of 600: Deputatskiy
# Not Found
# Processing record 93 of 600: Saint george
# Not Found
# Processing record 94 of 600: Washim
# Not Found
# Processing record 95 of 600: Busselton
# Not Found
# Processing record 96 of 600: Port alfred
# Not Found
# Processing record 97 of 600: Saint-philippe
# Not Found
# Processing record 98 of 600: Maniitsoq
# Not Found
# Processing record 99 of 600: Rajo khanani
# Not Found
# Processing record 100 of 600: Guanare
# Not Found
# Processing record 101 of 600: Kapaa
# Not Found
# Processing record 102 of 600: Hermanus
# Not Found
# Processing record 103 of 600: Cape town
# Not Found
# Processing record 104 of 600: Price
# Not Found
# Processing record 105 of 600: Osoyoos
# Not Found
# Processing record 106 of 600: Presidencia roque saenz pena
# Not Found
# Processing record 107 of 600: Nanyamba
# Not Found
# Processing record 108 of 600: Dikson
# Not Found
# Processing record 109 of 600: Ostrovnoy
# Not Found
# Processing record 110 of 600: Punta arenas
# Not Found
# Processing record 111 of 600: Mareeba
# Not Found
# Processing record 112 of 600: East london
# Not Found
# Processing record 113 of 600: Meulaboh
# Not Found
# Processing record 114 of 600: Saint-augustin
# Not Found
# Processing record 115 of 600: Mackay
# Not Found
# Processing record 116 of 600: Chiredzi
# Not Found
# Processing record 117 of 600: Arraial do cabo
# Not Found
# Processing record 118 of 600: Souillac
# Not Found
# Processing record 119 of 600: Mikhaylovka
# Not Found
# Processing record 120 of 600: Tasiilaq
# Not Found
# Processing record 121 of 600: Tamluk
# Not Found
# Processing record 122 of 600: Belushya guba
# Not Found
# Processing record 123 of 600: Barentsburg
# Not Found
# Processing record 124 of 600: Camacha
# Not Found
# Processing record 125 of 600: Nouadhibou
# Not Found
# Processing record 126 of 600: Mar del plata
# Not Found
# Processing record 127 of 600: Busselton
# Not Found
# Processing record 128 of 600: Moita
# Not Found
# Processing record 129 of 600: Kulevcha
# Not Found
# Processing record 130 of 600: Port alfred
# Not Found
# Processing record 131 of 600: Hithadhoo
# Not Found
# Processing record 132 of 600: Gweru
# Not Found
# Processing record 133 of 600: Bengkulu
# Not Found
# Processing record 134 of 600: Suchilquitongo
# Not Found
# Processing record 135 of 600: Batagay-alyta
# Not Found
# Processing record 136 of 600: Carnarvon
# Not Found
# Processing record 137 of 600: Tsihombe
# Not Found
# Processing record 138 of 600: Havre-saint-pierre
# Not Found
# Processing record 139 of 600: Souillac
# Not Found
# Processing record 140 of 600: Busselton
# Not Found
# Processing record 141 of 600: New norfolk
# Not Found
# Processing record 142 of 600: Aklavik
# Not Found
# Processing record 143 of 600: Taolanaro
# Not Found
# Processing record 144 of 600: Cacule
# Not Found
# Processing record 145 of 600: Nome
# Not Found
# Processing record 146 of 600: Bathsheba
# Not Found
# Processing record 147 of 600: Illoqqortoormiut
# Not Found
# Processing record 148 of 600: Hilo
# Not Found
# Processing record 149 of 600: Flinders
# Not Found
# Processing record 150 of 600: Qaanaaq
# Not Found
# Processing record 151 of 600: Rikitea
# Not Found
# Processing record 152 of 600: Auki
# Not Found
# Processing record 153 of 600: Arraial do cabo
# Not Found
# Processing record 154 of 600: Vaitupu
# Not Found
# Processing record 155 of 600: Cape town
# Not Found
# Processing record 156 of 600: Vaitupu
# Not Found
# Processing record 157 of 600: Vaini
# Not Found
# Processing record 158 of 600: Krasnoselkup
# Not Found
# Processing record 159 of 600: Sur
# Not Found
# Processing record 160 of 600: Atambua
# Not Found
# Processing record 161 of 600: La rioja
# Not Found
# Processing record 162 of 600: Tuktoyaktuk
# Not Found
# Processing record 163 of 600: Tessalit
# Not Found
# Processing record 164 of 600: Mar del plata
# Not Found
# Processing record 165 of 600: Bethel
# Not Found
# Processing record 166 of 600: Saint-georges
# Not Found
# Processing record 167 of 600: Punta arenas
# Not Found
# Processing record 168 of 600: Kangaatsiaq
# Not Found
# Processing record 169 of 600: Svetlogorsk
# Not Found
# Processing record 170 of 600: Talnakh
# Not Found
# Processing record 171 of 600: Ngukurr
# Not Found
# Processing record 172 of 600: Barrow
# Not Found
# Processing record 173 of 600: Yining
# Not Found
# Processing record 174 of 600: Cabo san lucas
# Not Found
# Processing record 175 of 600: Biscarrosse
# Not Found
# Processing record 176 of 600: Chuy
# Not Found
# Processing record 177 of 600: Berlevag
# Not Found
# Processing record 178 of 600: Karamken
# Not Found
# Processing record 179 of 600: Ushuaia
# Not Found
# Processing record 180 of 600: Pevek
# Not Found
# Processing record 181 of 600: Saldanha
# Not Found
# Processing record 182 of 600: Carnarvon
# Not Found
# Processing record 183 of 600: Port alfred
# Not Found
# Processing record 184 of 600: Vila
# Not Found
# Processing record 185 of 600: Norman wells
# Not Found
# Processing record 186 of 600: Bluff
# Not Found
# Processing record 187 of 600: Avarua
# Not Found
# Processing record 188 of 600: Vaini
# Not Found
# Processing record 189 of 600: Hilo
# Not Found
# Processing record 190 of 600: Mosquera
# Not Found
# Processing record 191 of 600: East london
# Not Found
# Processing record 192 of 600: Quelimane
# Not Found
# Processing record 193 of 600: Talwara
# Not Found
# Processing record 194 of 600: Conceicao da barra
# Not Found
# Processing record 195 of 600: East london
# Not Found
# Processing record 196 of 600: Huarmey
# Not Found
# Processing record 197 of 600: Yellowknife
# Not Found
# Processing record 198 of 600: Puerto ayora
# Not Found
# Processing record 199 of 600: Yellowknife
# Not Found
# Processing record 200 of 600: Fortuna
# Not Found
# Processing record 201 of 600: Lelydorp
# Not Found
# Processing record 202 of 600: Ushuaia
# Not Found
# Processing record 203 of 600: Kenora
# Not Found
# Processing record 204 of 600: Lagoa
# Not Found
# Processing record 205 of 600: Jamestown
# Not Found
# Processing record 206 of 600: Rikitea
# Not Found
# Processing record 207 of 600: Santa marta
# Not Found
# Processing record 208 of 600: Azovo
# Not Found
# Processing record 209 of 600: Busselton
# Not Found
# Processing record 210 of 600: Jamestown
# Not Found
# Processing record 211 of 600: Oyem
# Not Found
# Processing record 212 of 600: Butaritari
# Not Found
# Processing record 213 of 600: Port elizabeth
# Not Found
# Processing record 214 of 600: Burnie
# Not Found
# Processing record 215 of 600: Souillac
# Not Found
# Processing record 216 of 600: Nelson bay
# Not Found
# Processing record 217 of 600: Arraial do cabo
# Not Found
# Processing record 218 of 600: Rikitea
# Not Found
# Processing record 219 of 600: Rocky mountain house
# Not Found
# Processing record 220 of 600: Nome
# Not Found
# Processing record 221 of 600: Palmerston
# Not Found
# Processing record 222 of 600: Tuktoyaktuk
# Not Found
# Processing record 223 of 600: Barrow
# Not Found
# Processing record 224 of 600: Saldanha
# Not Found
# Processing record 225 of 600: Mataura
# Not Found
# Processing record 226 of 600: Rawlins
# Not Found
# Processing record 227 of 600: Hilo
# Not Found
# Processing record 228 of 600: Hermanus
# Not Found
# Processing record 229 of 600: Bubaque
# Not Found
# Processing record 230 of 600: Avarua
# Not Found
# Processing record 231 of 600: Wad rawah
# Not Found
# Processing record 232 of 600: Victoria
# Not Found
# Processing record 233 of 600: Jamestown
# Not Found
# Processing record 234 of 600: Turan
# Not Found
# Processing record 235 of 600: Ponta do sol
# Not Found
# Processing record 236 of 600: Koumac
# Not Found
# Processing record 237 of 600: Qostanay
# Not Found
# Processing record 238 of 600: Hermanus
# Not Found
# Processing record 239 of 600: Qaanaaq
# Not Found
# Processing record 240 of 600: Sabang
# Not Found
# Processing record 241 of 600: Namibe
# Not Found
# Processing record 242 of 600: Constitucion
# Not Found
# Processing record 243 of 600: Grand-santi
# Not Found
# Processing record 244 of 600: Rikitea
# Not Found
# Processing record 245 of 600: Vaini
# Not Found
# Processing record 246 of 600: Ojinaga
# Not Found
# Processing record 247 of 600: Ponta do sol
# Not Found
# Processing record 248 of 600: Tumannyy
# Not Found
# Processing record 249 of 600: Puerto ayora
# Not Found
# Processing record 250 of 600: Hilo
# Not Found
# Processing record 251 of 600: Hilo
# Not Found
# Processing record 252 of 600: Hithadhoo
# Not Found
# Processing record 253 of 600: Zaporizhzhya
# Not Found
# Processing record 254 of 600: Mareeba
# Not Found
# Processing record 255 of 600: Illoqqortoormiut
# Not Found
# Processing record 256 of 600: San quintin
# Not Found
# Processing record 257 of 600: Bethlehem
# Not Found
# Processing record 258 of 600: Gurupi
# Not Found
# Processing record 259 of 600: Sampit
# Not Found
# Processing record 260 of 600: Leningradskiy
# Not Found
# Processing record 261 of 600: Grand river south east
# Not Found
# Processing record 262 of 600: Oussouye
# Not Found
# Processing record 263 of 600: Port hardy
# Not Found
# Processing record 264 of 600: Rikitea
# Not Found
# Processing record 265 of 600: Port elizabeth
# Not Found
# Processing record 266 of 600: Albany
# Not Found
# Processing record 267 of 600: Grindavik
# Not Found
# Processing record 268 of 600: Georgetown
# Not Found
# Processing record 269 of 600: Marystown
# Not Found
# Processing record 270 of 600: Albany
# Not Found
# Processing record 271 of 600: Pacific grove
# Not Found
# Processing record 272 of 600: Kapaa
# Not Found
# Processing record 273 of 600: Grand river south east
# Not Found
# Processing record 274 of 600: Sola
# Not Found
# Processing record 275 of 600: Illoqqortoormiut
# Not Found
# Processing record 276 of 600: Linxia
# Not Found
# Processing record 277 of 600: Puerto ayora
# Not Found
# Processing record 278 of 600: Viedma
# Not Found
# Processing record 279 of 600: Ayan
# Not Found
# Processing record 280 of 600: Busselton
# Not Found
# Processing record 281 of 600: Ribeira grande
# Not Found
# Processing record 282 of 600: Carnarvon
# Not Found
# Processing record 283 of 600: Mar del plata
# Not Found
# Processing record 284 of 600: Erenhot
# Not Found
# Processing record 285 of 600: Gallup
# Not Found
# Processing record 286 of 600: East london
# Not Found
# Processing record 287 of 600: Ponta do sol
# Not Found
# Processing record 288 of 600: Vaini
# Not Found
# Processing record 289 of 600: Qaanaaq
# Not Found
# Processing record 290 of 600: Punta arenas
# Not Found
# Processing record 291 of 600: Mataura
# Not Found
# Processing record 292 of 600: Comodoro rivadavia
# Not Found
# Processing record 293 of 600: Tupik
# Not Found
# Processing record 294 of 600: New norfolk
# Not Found
# Processing record 295 of 600: Atuona
# Not Found
# Processing record 296 of 600: Sentyabrskiy
# Not Found
# Processing record 297 of 600: Bambous virieux
# Not Found
# Processing record 298 of 600: Kapaa
# Not Found
# Processing record 299 of 600: Zarichne
# Not Found
# Processing record 300 of 600: Pevek
# Not Found
# Processing record 301 of 600: Hilo
# Not Found
# Processing record 302 of 600: Puerto ayora
# Not Found
# Processing record 303 of 600: Bambous virieux
# Not Found
# Processing record 304 of 600: Hermanus
# Not Found
# Processing record 305 of 600: Northam
# Not Found
# Processing record 306 of 600: Hermanus
# Not Found
# Processing record 307 of 600: Karaul
# Not Found
# Processing record 308 of 600: Vaini
# Not Found
# Processing record 309 of 600: Katsuura
# Not Found
# Processing record 310 of 600: Maldonado
# Not Found
# Processing record 311 of 600: Belmonte
# Not Found
# Processing record 312 of 600: Busselton
# Not Found
# Processing record 313 of 600: Puerto ayora
# Not Found
# Processing record 314 of 600: Avarua
# Not Found
# Processing record 315 of 600: Puerto ayora
# Not Found
# Processing record 316 of 600: Passo de camaragibe
# Not Found
# Processing record 317 of 600: Mataura
# Not Found
# Processing record 318 of 600: Hermanus
# Not Found
# Processing record 319 of 600: Koungou
# Not Found
# Processing record 320 of 600: Naze
# Not Found
# Processing record 321 of 600: Bethel
# Not Found
# Processing record 322 of 600: Ancud
# Not Found
# Processing record 323 of 600: Taolanaro
# Not Found
# Processing record 324 of 600: Arraial do cabo
# Not Found
# Processing record 325 of 600: Vicam
# Not Found
# Processing record 326 of 600: Qaanaaq
# Not Found
# Processing record 327 of 600: Bluff
# Not Found
# Processing record 328 of 600: Punta arenas
# Not Found
# Processing record 329 of 600: Punta arenas
# Not Found
# Processing record 330 of 600: Leh
# Not Found
# Processing record 331 of 600: Havoysund
# Not Found
# Processing record 332 of 600: Ishigaki
# Not Found
# Processing record 333 of 600: Victoria
# Not Found
# Processing record 334 of 600: Provideniya
# Not Found
# Processing record 335 of 600: Mar del plata
# Not Found
# Processing record 336 of 600: Narsaq
# Not Found
# Processing record 337 of 600: Kodiak
# Not Found
# Processing record 338 of 600: Clyde river
# Not Found
# Processing record 339 of 600: Souillac
# Not Found
# Processing record 340 of 600: Biak
# Not Found
# Processing record 341 of 600: New norfolk
# Not Found
# Processing record 342 of 600: Camacha
# Not Found
# Processing record 343 of 600: Chara
# Not Found
# Processing record 344 of 600: Goderich
# Not Found
# Processing record 345 of 600: Rikitea
# Not Found
# Processing record 346 of 600: Samusu
# Not Found
# Processing record 347 of 600: Punta arenas
# Not Found
# Processing record 348 of 600: Hilo
# Not Found
# Processing record 349 of 600: Cape town
# Not Found
# Processing record 350 of 600: Kavieng
# Not Found
# Processing record 351 of 600: Lebu
# Not Found
# Processing record 352 of 600: Rikitea
# Not Found
# Processing record 353 of 600: Longyearbyen
# Not Found
# Processing record 354 of 600: Busselton
# Not Found
# Processing record 355 of 600: Port alfred
# Not Found
# Processing record 356 of 600: Victor harbor
# Not Found
# Processing record 357 of 600: Cabedelo
# Not Found
# Processing record 358 of 600: Vaini
# Not Found
# Processing record 359 of 600: Ntcheu
# Not Found
# Processing record 360 of 600: Satitoa
# Not Found
# Processing record 361 of 600: Albany
# Not Found
# Processing record 362 of 600: Hermanus
# Not Found
# Processing record 363 of 600: Caohe
# Not Found
# Processing record 364 of 600: Samusu
# Not Found
# Processing record 365 of 600: Thompson
# Not Found
# Processing record 366 of 600: Mnogovershinnyy
# Not Found
# Processing record 367 of 600: Albany
# Not Found
# Processing record 368 of 600: Tshikapa
# Not Found
# Processing record 369 of 600: Bredasdorp
# Not Found
# Processing record 370 of 600: Cape town
# Not Found
# Processing record 371 of 600: Pangnirtung
# Not Found
# Processing record 372 of 600: Victoria
# Not Found
# Processing record 373 of 600: Egvekinot
# Not Found
# Processing record 374 of 600: Touros
# Not Found
# Processing record 375 of 600: Rikitea
# Not Found
# Processing record 376 of 600: Butaritari
# Not Found
# Processing record 377 of 600: Rikitea
# Not Found
# Processing record 378 of 600: Abonnema
# Not Found
# Processing record 379 of 600: Busselton
# Not Found
# Processing record 380 of 600: Zhigansk
# Not Found
# Processing record 381 of 600: Faanui
# Not Found
# Processing record 382 of 600: Shache
# Not Found
# Processing record 383 of 600: Hanstholm
# Not Found
# Processing record 384 of 600: Esperance
# Not Found
# Processing record 385 of 600: Busselton
# Not Found
# Processing record 386 of 600: Grand river south east
# Not Found
# Processing record 387 of 600: Geraldton
# Not Found
# Processing record 388 of 600: Mataura
# Not Found
# Processing record 389 of 600: Jiayuguan
# Not Found
# Processing record 390 of 600: Amapa
# Not Found
# Processing record 391 of 600: High level
# Not Found
# Processing record 392 of 600: Albany
# Not Found
# Processing record 393 of 600: Riyadh
# Not Found
# Processing record 394 of 600: Bluff
# Not Found
# Processing record 395 of 600: Praya
# Not Found
# Processing record 396 of 600: Codrington
# Not Found
# Processing record 397 of 600: Bluff
# Not Found
# Processing record 398 of 600: Tsihombe
# Not Found
# Processing record 399 of 600: Mataura
# Not Found
# Processing record 400 of 600: Sept-iles
# Not Found
# Processing record 401 of 600: Barentsburg
# Not Found
# Processing record 402 of 600: Senno
# Not Found
# Processing record 403 of 600: Longyearbyen
# Not Found
# Processing record 404 of 600: Jamestown
# Not Found
# Processing record 405 of 600: Nabire
# Not Found
# Processing record 406 of 600: Mataura
# Not Found
# Processing record 407 of 600: Ahipara
# Not Found
# Processing record 408 of 600: Hovd
# Not Found
# Processing record 409 of 600: Samfya
# Not Found
# Processing record 410 of 600: Dingle
# Not Found
# Processing record 411 of 600: Durg
# Not Found
# Processing record 412 of 600: Molochnoye
# Not Found
# Processing record 413 of 600: Khatanga
# Not Found
# Processing record 414 of 600: Hithadhoo
# Not Found
# Processing record 415 of 600: Port alfred
# Not Found
# Processing record 416 of 600: Hobart
# Not Found
# Processing record 417 of 600: Grindavik
# Not Found
# Processing record 418 of 600: Jamestown
# Not Found
# Processing record 419 of 600: Vaini
# Not Found
# Processing record 420 of 600: Yining
# Not Found
# Processing record 421 of 600: Attawapiskat
# Not Found
# Processing record 422 of 600: Barentsburg
# Not Found
# Processing record 423 of 600: Ahipara
# Not Found
# Processing record 424 of 600: Port alfred
# Not Found
# Processing record 425 of 600: Hithadhoo
# Not Found
# Processing record 426 of 600: Bengkulu
# Not Found
# Processing record 427 of 600: Rikitea
# Not Found
# Processing record 428 of 600: Port elizabeth
# Not Found
# Processing record 429 of 600: Qaanaaq
# Not Found
# Processing record 430 of 600: Puerto ayora
# Not Found
# Processing record 431 of 600: Bredasdorp
# Not Found
# Processing record 432 of 600: East london
# Not Found
# Processing record 433 of 600: Jamestown
# Not Found
# Processing record 434 of 600: Puerto ayora
# Not Found
# Processing record 435 of 600: Lander
# Not Found
# Processing record 436 of 600: Barrow
# Not Found
# Processing record 437 of 600: Sikonge
# Not Found
# Processing record 438 of 600: Avarua
# Not Found
# Processing record 439 of 600: Patur
# Not Found
# Processing record 440 of 600: Albany
# Not Found
# Processing record 441 of 600: Ahipara
# Not Found
# Processing record 442 of 600: Dingle
# Not Found
# Processing record 443 of 600: Amderma
# Not Found
# Processing record 444 of 600: Rundu
# Not Found
# Processing record 445 of 600: Carnarvon
# Not Found
# Processing record 446 of 600: Albany
# Not Found
# Processing record 447 of 600: Novyy urengoy
# Not Found
# Processing record 448 of 600: Pangai
# Not Found
# Processing record 449 of 600: College
# Not Found
# Processing record 450 of 600: Bengkulu
# Not Found
# Processing record 451 of 600: Rikitea
# Not Found
# Processing record 452 of 600: Ushuaia
# Not Found
# Processing record 453 of 600: Likoporia
# Not Found
# Processing record 454 of 600: Cape town
# Not Found
# Processing record 455 of 600: Souillac
# Not Found
# Processing record 456 of 600: Qaanaaq
# Not Found
# Processing record 457 of 600: Saint-philippe
# Not Found
# Processing record 458 of 600: Wilmington
# Not Found
# Processing record 459 of 600: Rikitea
# Not Found
# Processing record 460 of 600: Pitimbu
# Not Found
# Processing record 461 of 600: Anadyr
# Not Found
# Processing record 462 of 600: Erie
# Not Found
# Processing record 463 of 600: New norfolk
# Not Found
# Processing record 464 of 600: Mahebourg
# Not Found
# Processing record 465 of 600: Arraial do cabo
# Not Found
# Processing record 466 of 600: Acarau
# Not Found
# Processing record 467 of 600: Rikitea
# Not Found
# Processing record 468 of 600: Tuatapere
# Not Found
# Processing record 469 of 600: Torbay
# Not Found
# Processing record 470 of 600: Karachi
# Not Found
# Processing record 471 of 600: Talaya
# Not Found
# Processing record 472 of 600: Yorosso
# Not Found
# Processing record 473 of 600: Buariki
# Not Found
# Processing record 474 of 600: Ribeira brava
# Not Found
# Processing record 475 of 600: Galesong
# Not Found
# Processing record 476 of 600: Tiksi
# Not Found
# Processing record 477 of 600: Talnakh
# Not Found
# Processing record 478 of 600: Naze
# Not Found
# Processing record 479 of 600: Maceio
# Not Found
# Processing record 480 of 600: Aden
# Not Found
# Processing record 481 of 600: Grand river south east
# Not Found
# Processing record 482 of 600: Dakar
# Not Found
# Processing record 483 of 600: Ushuaia
# Not Found
# Processing record 484 of 600: Komsomolskiy
# Not Found
# Processing record 485 of 600: Ribeira grande
# Not Found
# Processing record 486 of 600: Rikitea
# Not Found
# Processing record 487 of 600: Cayeli
# Not Found
# Processing record 488 of 600: Saskylakh
# Not Found
# Processing record 489 of 600: Ranong
# Not Found
# Processing record 490 of 600: Broome
# Not Found
# Processing record 491 of 600: Puerto ayora
# Not Found
# Processing record 492 of 600: Faanui
# Not Found
# Processing record 493 of 600: Sindand
# Not Found
# Processing record 494 of 600: Cape town
# Not Found
# Processing record 495 of 600: Belushya guba
# Not Found
# Processing record 496 of 600: Poum
# Not Found
# Processing record 497 of 600: Thompson
# Not Found
# Processing record 498 of 600: Comodoro rivadavia
# Not Found
# Processing record 499 of 600: Albany
# Not Found
# Processing record 500 of 600: Kitgum
# Not Found
# Processing record 501 of 600: Saravan
# Not Found
# Processing record 502 of 600: Karkaralinsk
# Not Found
# Processing record 503 of 600: Saskylakh
# Not Found
# Processing record 504 of 600: Hermanus
# Not Found
# Processing record 505 of 600: Atuona
# Not Found
# Processing record 506 of 600: Atbasar
# Not Found
# Processing record 507 of 600: Kavaratti
# Not Found
# Processing record 508 of 600: Iwanai
# Not Found
# Processing record 509 of 600: Qaanaaq
# Not Found
# Processing record 510 of 600: Guerrero negro
# Not Found
# Processing record 511 of 600: Hermanus
# Not Found
# Processing record 512 of 600: Attawapiskat
# Not Found
# Processing record 513 of 600: Bluff
# Not Found
# Processing record 514 of 600: Ossora
# Not Found
# Processing record 515 of 600: Glubokoe
# Not Found
# Processing record 516 of 600: Busselton
# Not Found
# Processing record 517 of 600: Vostok
# Not Found
# Processing record 518 of 600: Klaksvik
# Not Found
# Processing record 519 of 600: Andra
# Not Found
# Processing record 520 of 600: Kaitangata
# Not Found
# Processing record 521 of 600: Upernavik
# Not Found
# Processing record 522 of 600: Bredasdorp
# Not Found
# Processing record 523 of 600: Barrow
# Not Found
# Processing record 524 of 600: Hilo
# Not Found
# Processing record 525 of 600: Ternate
# Not Found
# Processing record 526 of 600: Rikitea
# Not Found
# Processing record 527 of 600: Albany
# Not Found
# Processing record 528 of 600: Sao filipe
# Not Found
# Processing record 529 of 600: Tuatapere
# Not Found
# Processing record 530 of 600: Albany
# Not Found
# Processing record 531 of 600: Barentsburg
# Not Found
# Processing record 532 of 600: Tasiilaq
# Not Found
# Processing record 533 of 600: Serik
# Not Found
# Processing record 534 of 600: Mataura
# Not Found
# Processing record 535 of 600: Sao filipe
# Not Found
# Processing record 536 of 600: Bathurst
# Not Found
# Processing record 537 of 600: Mataura
# Not Found
# Processing record 538 of 600: Lermontovka
# Not Found
# Processing record 539 of 600: Saint-philippe
# Not Found
# Processing record 540 of 600: Dikson
# Not Found
# Processing record 541 of 600: Krasnousolskiy
# Not Found
# Processing record 542 of 600: Tshikapa
# Not Found
# Processing record 543 of 600: Taolanaro
# Not Found
# Processing record 544 of 600: San quintin
# Not Found
# Processing record 545 of 600: Vilhena
# Not Found
# Processing record 546 of 600: Rikitea
# Not Found
# Processing record 547 of 600: Hilo
# Not Found
# Processing record 548 of 600: Dolbeau
# Not Found
# Processing record 549 of 600: Avarua
# Not Found
# Processing record 550 of 600: Cape town
# Not Found
# Processing record 551 of 600: Pombia
# Not Found
# Processing record 552 of 600: Castro
# Not Found
# Processing record 553 of 600: Pacific grove
# Not Found
# Processing record 554 of 600: Yellowknife
# Not Found
# Processing record 555 of 600: Narasannapeta
# Not Found
# Processing record 556 of 600: Saint-philippe
# Not Found
# Processing record 557 of 600: Oktyabrskoye
# Not Found
# Processing record 558 of 600: San quintin
# Not Found
# Processing record 559 of 600: Ushuaia
# Not Found
# Processing record 560 of 600: Laurel
# Not Found
# Processing record 561 of 600: Tuktoyaktuk
# Not Found
# Processing record 562 of 600: Zhigansk
# Not Found
# Processing record 563 of 600: Paradwip
# Not Found
# Processing record 564 of 600: Saint-pierre
# Not Found
# Processing record 565 of 600: Yellowknife
# Not Found
# Processing record 566 of 600: Suez
# Not Found
# Processing record 567 of 600: Kodiak
# Not Found
# Processing record 568 of 600: Cape town
# Not Found
# Processing record 569 of 600: Saskylakh
# Not Found
# Processing record 570 of 600: Puerto ayora
# Not Found
# Processing record 571 of 600: Mataura
# Not Found
# Processing record 572 of 600: Paradwip
# Not Found
# Processing record 573 of 600: San cristobal
# Not Found
# Processing record 574 of 600: Castro
# Not Found
# Processing record 575 of 600: Lebu
# Not Found
# Processing record 576 of 600: Puerto suarez
# Not Found
# Processing record 577 of 600: Lata
# Not Found
# Processing record 578 of 600: Barentsburg
# Not Found
# Processing record 579 of 600: Ushuaia
# Not Found
# Processing record 580 of 600: Busselton
# Not Found
# Processing record 581 of 600: Souillac
# Not Found
# Processing record 582 of 600: Bethel
# Not Found
# Processing record 583 of 600: Tuatapere
# Not Found
# Processing record 584 of 600: Port hardy
# Not Found
# Processing record 585 of 600: Thompson
# Not Found
# Processing record 586 of 600: Bredasdorp
# Not Found
# Processing record 587 of 600: Adre
# Not Found
# Processing record 588 of 600: Belushya guba
# Not Found
# Processing record 589 of 600: Sitka
# Not Found
# Processing record 590 of 600: Bluff
# Not Found
# Processing record 591 of 600: Nantucket
# Not Found
# Processing record 592 of 600: Zemio
# Not Found
# Processing record 593 of 600: Namibe
# Not Found
# Processing record 594 of 600: Avarua
# Not Found
# Processing record 595 of 600: Hilo
# Not Found
# Processing record 596 of 600: Nanortalik
# Not Found
# Processing record 597 of 600: Hermanus
# Not Found
# Processing record 598 of 600: Port hawkesbury
# Not Found
# Processing record 599 of 600: Mataura
# Not Found
# Processing record 600 of 600: Thompson
# Not Found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#export
city_df.to_csv("cities.csv")

# %%
#show
city_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#lat x temp y
temp = city_df.plot.scatter(x="Latitude", y="Max Temp (F)", title=f"City Latitude vs. Max Temperature",
                 c="blue", edgecolor="black", grid=True, s=35)
plt.savefig("output_data/citymaxtemp.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-ecd80468217a> in <module>()
#       1 #lat x temp y
#       2 temp = city_df.plot.scatter(x="Latitude", y="Max Temp (F)", title=f"City Latitude vs. Max Temperature",
# ----> 3                  c="blue", edgecolor="black", grid=True, s=35)
#       4 plt.savefig("output_data/citymaxtemp.png")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     817         if is_integer(y) and not self.data.columns.holds_integer():
#     818             y = self.data.columns[y]
# --> 819         if len(self.data[x]._get_numeric_data()) == 0:
#     820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#lat x hum y
hum = city_df.plot.scatter(x="Latitude", y="Humidity (%)", c="blue", title=f"City Latitude vs. Humidity",
                           edgecolor="black", grid=True, s=35, alpha = 0.5)
plt.savefig("output_data/cityhumidity.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-c6214ce90145> in <module>()
#       1 #lat x hum y
#       2 hum = city_df.plot.scatter(x="Latitude", y="Humidity (%)", c="blue", title=f"City Latitude vs. Humidity",
# ----> 3                            edgecolor="black", grid=True, s=35, alpha = 0.5)
#       4 plt.savefig("output_data/cityhumidity.png")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, x, y, **kwargs)
#     817         if is_integer(y) and not self.data.columns.holds_integer():
#     818             y = self.data.columns[y]
# --> 819         if len(self.data[x]._get_numeric_data()) == 0:
#     820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#lat x clouds y
cloudiness = city_df.plot.scatter(x="Latitude", y="Cloudiness (%)", c="blue", title=f"City Latitude vs. Cloudiness)",
                            edgecolor="black", grid=True, s=35)
plt.savefig("output_data/citycloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
wind = city_df.plot.scatter(x="Latitude", y="Wind Speed (mph)", c="blue", title=f"City Latitude vs. Wind Speed)",
                        edgecolor="black", grid=True, s=35)
plt.savefig("output_data/citywindspeeds.png")
